# %%
from astropy.cosmology import Planck18
from astropy.coordinates import SkyCoord
import astropy.units as u

from astropy.table import Table, Column
import pandas as pd
import os
import glob
import random

# %%
# original files are found here https://data.desi.lbl.gov/public/dr1/survey/catalogs/dr1/LSS/iron/LSScats/v1.5/
lss_data_N = Table.read("data/QSO_NGC_clustering.dat.fits")

# %%
# Filter one-dimensional columns
names_N = [name for name in lss_data_N.colnames if len(lss_data_N[name].shape) <= 1]

# Convert to pandas DataFrame with only valid columns
df_N = lss_data_N[names_N].to_pandas()

df_N["ORIGIN_FILE"] = "NGC"

# %%
df_NGC_1 = df_N[
    (df_N['RA'] > 110) & (df_N['RA'] < 260) &
    (df_N['DEC'] > -10) & (df_N['DEC'] < 8) 
]

df_NGC_2 = df_N[
    (df_N['RA'] > 180) & (df_N['RA'] < 260) &
    (df_N['DEC'] > 30) & (df_N['DEC'] < 40) 
]

# %%
df_NGC_1.rename(columns={'Z': 'REDSHIFT'}, inplace=True)
df_NGC_2.rename(columns={'Z': 'REDSHIFT'}, inplace=True)
# Out:
# C:\Users\intercall\AppData\Local\Temp\ipykernel_38472\4124048540.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_NGC_1.rename(columns={'Z': 'REDSHIFT'}, inplace=True)
# C:\Users\intercall\AppData\Local\Temp\ipykernel_38472\4124048540.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_NGC_2.rename(columns={'Z': 'REDSHIFT'}, inplace=True)

# %%
cosmo = Planck18 # define cosmology

def parameters_for_files(df):
    redshift = df['REDSHIFT'].values
    ra = df['RA'].values
    dec = df['DEC'].values

    # comoving distance
    d_comov = cosmo.comoving_distance(redshift).to(u.Mpc).value
    df['COMOVING_DISTANCE'] = d_comov

    coords = SkyCoord(ra=ra*u.deg, dec=dec*u.deg, distance=d_comov*u.Mpc, frame='icrs')

    # cartesian coordinates
    x = coords.cartesian.x.value
    y = coords.cartesian.y.value
    z = coords.cartesian.z.value 

    df['X'] = coords.cartesian.x.to(u.Mpc).value
    df['Y'] = coords.cartesian.y.to(u.Mpc).value
    df['Z'] = coords.cartesian.z.to(u.Mpc).value 
    return df

# %%
def save_ecsv(df, name):
    targetid = Column(df["TARGETID"].values)
    x = Column(df["X"].values, unit=u.Mpc)
    y = Column(df["Y"].values, unit=u.Mpc)
    z = Column(df["Z"].values, unit=u.Mpc)
    ra = Column(df["RA"].values, unit=u.deg)
    dec = Column(df["DEC"].values, unit=u.deg)
    redshift = Column(df["REDSHIFT"].values)

    table = Table([targetid, x, y, z, ra, dec, redshift],
                  names=("TARGETID", "X", "Y", "Z", "RA", "DEC", "REDSHIFT"))
    filename = f"create_files/QSO_{name}_clustering_data.ecsv"
    table.write(filename, format="ascii.ecsv", overwrite=True)
    print(f"Saved file: {filename}")

save_ecsv(parameters_for_files(df_NGC_1), "NGC1")
save_ecsv(parameters_for_files(df_NGC_2), "NGC2")
# Out:
# C:\Users\intercall\AppData\Local\Temp\ipykernel_38472\1587481534.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['COMOVING_DISTANCE'] = d_comov
# C:\Users\intercall\AppData\Local\Temp\ipykernel_38472\1587481534.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['X'] = coords.cartesian.x.to(u.Mpc).value
# C:\Users\intercall\AppData\Local\Temp\ipykernel_38472\1587481534.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Y'] = coords.cartesian.y.to(u.Mpc).value
# C:\Users\intercall\AppData\Local\Temp\ipykernel_38472\1587481534.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Z'] = coords.cartesian.z.to(u.Mpc).value
# Saved file: create_files/QSO_NGC1_clustering_data.ecsv
# C:\Users\intercall\AppData\Local\Temp\ipykernel_38472\1587481534.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['COMOVING_DISTANCE'] = d_comov
# C:\Users\intercall\AppData\Local\Temp\ipykernel_38472\1587481534.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['X'] = coords.cartesian.x.to(u.Mpc).value
# C:\Users\intercall\AppData\Local\Temp\ipykernel_38472\1587481534.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Y'] = coords.cartesian.y.to(u.Mpc).value
# C:\Users\intercall\AppData\Local\Temp\ipykernel_38472\1587481534.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Z'] = coords.cartesian.z.to(u.Mpc).value
# Saved file: create_files/QSO_NGC2_clustering_data.ecsv

# %%
regions = {'NGC_1': df_NGC_1, 'NGC_2': df_NGC_2}

# %% [markdown]
# # For random file:

# %%
cosmo = Planck18 # define cosmology

# %%
ran_files_NGC = sorted(glob.glob("data/QSO_NGC_*_clustering.ran.fits"))

# %%
output_dir = "data_100_random"

# %%
file_use_count = {i: 0 for i in range(len(ran_files_NGC))}

for region_name, region_df in regions.items():
    used_indices = set()
    n_files = len(ran_files_NGC)
    n_rows = len(region_df)

    for j in range(100):
        if len(used_indices) == n_files:
            used_indices = set()

        available_indices = list(set(range(n_files)) - used_indices)
        file_index = random.choice(available_indices)
        used_indices.add(file_index)

        ran_table = Table.read(ran_files_NGC[file_index])
        ran_df = ran_table.to_pandas()

        ran_df_full = ran_table.to_pandas()

        if region_name == 'NGC_1':
            filtered_ran = ran_df_full[(ran_df_full['RA'] > 110) & (ran_df_full['RA'] < 260) &
                                    (ran_df_full['DEC'] > -10) & (ran_df_full['DEC'] < 8)]
        else:
            filtered_ran = ran_df_full[(ran_df_full['RA'] > 180) & (ran_df_full['RA'] < 260) &
                                    (ran_df_full['DEC'] > 30) & (ran_df_full['DEC'] < 40)]

        ran_df = filtered_ran.sample(n=n_rows, random_state=j).reset_index(drop=True)

        z_ran = ran_df['Z'].values
        d_comov = cosmo.comoving_distance(z_ran).to(u.Mpc)
        coords = SkyCoord(ra=ran_df['RA'].values * u.deg,
                          dec=ran_df['DEC'].values * u.deg,
                          distance=d_comov)


        output_table = Table({
            'TARGETID': ran_df['TARGETID'],
            'X': coords.cartesian.x.to(u.Mpc),
            'Y': coords.cartesian.y.to(u.Mpc),
            'Z': coords.cartesian.z.to(u.Mpc),
            'RA': ran_df['RA'],
            'DEC': ran_df['DEC'],
            'REDSHIFT': ran_df['Z'],
        })

        filename = f"{output_dir}/{region_name}_random_{j}.ecsv"
        output_table.write(filename, format='ascii.ecsv', overwrite=True)
        print(f"Saved file: {filename}")
# Out:
# Saved file: data_100_random/NGC_1_random_0.ecsv
# Saved file: data_100_random/NGC_1_random_1.ecsv
# Saved file: data_100_random/NGC_1_random_2.ecsv
# Saved file: data_100_random/NGC_1_random_3.ecsv
# Saved file: data_100_random/NGC_1_random_4.ecsv
# Saved file: data_100_random/NGC_1_random_5.ecsv
# Saved file: data_100_random/NGC_1_random_6.ecsv
# Saved file: data_100_random/NGC_1_random_7.ecsv
# Saved file: data_100_random/NGC_1_random_8.ecsv
# Saved file: data_100_random/NGC_1_random_9.ecsv
# Saved file: data_100_random/NGC_1_random_10.ecsv
# Saved file: data_100_random/NGC_1_random_11.ecsv
# Saved file: data_100_random/NGC_1_random_12.ecsv
# Saved file: data_100_random/NGC_1_random_13.ecsv
# Saved file: data_100_random/NGC_1_random_14.ecsv
# Saved file: data_100_random/NGC_1_random_15.ecsv
# Saved file: data_100_random/NGC_1_random_16.ecsv
# Saved file: data_100_random/NGC_1_random_17.ecsv
# Saved file: data_100_random/NGC_1_random_18.ecsv
# Saved file: data_100_random/NGC_1_random_19.ecsv
# Saved file: data_100_random/NGC_1_random_20.ecsv
# Saved file: data_100_random/NGC_1_random_21.ecsv
# Saved file: data_100_random/NGC_1_random_22.ecsv
# Saved file: data_100_random/NGC_1_random_23.ecsv
# Saved file: data_100_random/NGC_1_random_24.ecsv
# Saved file: data_100_random/NGC_1_random_25.ecsv
# Saved file: data_100_random/NGC_1_random_26.ecsv
# Saved file: data_100_random/NGC_1_random_27.ecsv
# Saved file: data_100_random/NGC_1_random_28.ecsv
# Saved file: data_100_random/NGC_1_random_29.ecsv
# Saved file: data_100_random/NGC_1_random_30.ecsv
# Saved file: data_100_random/NGC_1_random_31.ecsv
# Saved file: data_100_random/NGC_1_random_32.ecsv
# Saved file: data_100_random/NGC_1_random_33.ecsv
# Saved file: data_100_random/NGC_1_random_34.ecsv
# Saved file: data_100_random/NGC_1_random_35.ecsv
# Saved file: data_100_random/NGC_1_random_36.ecsv
# Saved file: data_100_random/NGC_1_random_37.ecsv
# Saved file: data_100_random/NGC_1_random_38.ecsv
# Saved file: data_100_random/NGC_1_random_39.ecsv
# Saved file: data_100_random/NGC_1_random_40.ecsv
# Saved file: data_100_random/NGC_1_random_41.ecsv
# Saved file: data_100_random/NGC_1_random_42.ecsv
# Saved file: data_100_random/NGC_1_random_43.ecsv
# Saved file: data_100_random/NGC_1_random_44.ecsv
# Saved file: data_100_random/NGC_1_random_45.ecsv
# Saved file: data_100_random/NGC_1_random_46.ecsv
# Saved file: data_100_random/NGC_1_random_47.ecsv
# Saved file: data_100_random/NGC_1_random_48.ecsv
# Saved file: data_100_random/NGC_1_random_49.ecsv
# Saved file: data_100_random/NGC_1_random_50.ecsv
# Saved file: data_100_random/NGC_1_random_51.ecsv
# Saved file: data_100_random/NGC_1_random_52.ecsv
# Saved file: data_100_random/NGC_1_random_53.ecsv
# Saved file: data_100_random/NGC_1_random_54.ecsv
# Saved file: data_100_random/NGC_1_random_55.ecsv
# Saved file: data_100_random/NGC_1_random_56.ecsv
# Saved file: data_100_random/NGC_1_random_57.ecsv
# Saved file: data_100_random/NGC_1_random_58.ecsv
# Saved file: data_100_random/NGC_1_random_59.ecsv
# Saved file: data_100_random/NGC_1_random_60.ecsv
# Saved file: data_100_random/NGC_1_random_61.ecsv
# Saved file: data_100_random/NGC_1_random_62.ecsv
# Saved file: data_100_random/NGC_1_random_63.ecsv
# Saved file: data_100_random/NGC_1_random_64.ecsv
# Saved file: data_100_random/NGC_1_random_65.ecsv
# Saved file: data_100_random/NGC_1_random_66.ecsv
# Saved file: data_100_random/NGC_1_random_67.ecsv
# Saved file: data_100_random/NGC_1_random_68.ecsv
# Saved file: data_100_random/NGC_1_random_69.ecsv
# Saved file: data_100_random/NGC_1_random_70.ecsv
# Saved file: data_100_random/NGC_1_random_71.ecsv
# Saved file: data_100_random/NGC_1_random_72.ecsv
# Saved file: data_100_random/NGC_1_random_73.ecsv
# Saved file: data_100_random/NGC_1_random_74.ecsv
# Saved file: data_100_random/NGC_1_random_75.ecsv
# Saved file: data_100_random/NGC_1_random_76.ecsv
# Saved file: data_100_random/NGC_1_random_77.ecsv
# Saved file: data_100_random/NGC_1_random_78.ecsv
# Saved file: data_100_random/NGC_1_random_79.ecsv
# Saved file: data_100_random/NGC_1_random_80.ecsv
# Saved file: data_100_random/NGC_1_random_81.ecsv
# Saved file: data_100_random/NGC_1_random_82.ecsv
# Saved file: data_100_random/NGC_1_random_83.ecsv
# Saved file: data_100_random/NGC_1_random_84.ecsv
# Saved file: data_100_random/NGC_1_random_85.ecsv
# Saved file: data_100_random/NGC_1_random_86.ecsv
# Saved file: data_100_random/NGC_1_random_87.ecsv
# Saved file: data_100_random/NGC_1_random_88.ecsv
# Saved file: data_100_random/NGC_1_random_89.ecsv
# Saved file: data_100_random/NGC_1_random_90.ecsv
# Saved file: data_100_random/NGC_1_random_91.ecsv
# Saved file: data_100_random/NGC_1_random_92.ecsv
# Saved file: data_100_random/NGC_1_random_93.ecsv
# Saved file: data_100_random/NGC_1_random_94.ecsv
# Saved file: data_100_random/NGC_1_random_95.ecsv
# Saved file: data_100_random/NGC_1_random_96.ecsv
# Saved file: data_100_random/NGC_1_random_97.ecsv
# Saved file: data_100_random/NGC_1_random_98.ecsv
# Saved file: data_100_random/NGC_1_random_99.ecsv
# Saved file: data_100_random/NGC_2_random_0.ecsv
# Saved file: data_100_random/NGC_2_random_1.ecsv
# Saved file: data_100_random/NGC_2_random_2.ecsv
# Saved file: data_100_random/NGC_2_random_3.ecsv
# Saved file: data_100_random/NGC_2_random_4.ecsv
# Saved file: data_100_random/NGC_2_random_5.ecsv
# Saved file: data_100_random/NGC_2_random_6.ecsv
# Saved file: data_100_random/NGC_2_random_7.ecsv
# Saved file: data_100_random/NGC_2_random_8.ecsv
# Saved file: data_100_random/NGC_2_random_9.ecsv
# Saved file: data_100_random/NGC_2_random_10.ecsv
# Saved file: data_100_random/NGC_2_random_11.ecsv
# Saved file: data_100_random/NGC_2_random_12.ecsv
# Saved file: data_100_random/NGC_2_random_13.ecsv
# Saved file: data_100_random/NGC_2_random_14.ecsv
# Saved file: data_100_random/NGC_2_random_15.ecsv
# Saved file: data_100_random/NGC_2_random_16.ecsv
# Saved file: data_100_random/NGC_2_random_17.ecsv
# Saved file: data_100_random/NGC_2_random_18.ecsv
# Saved file: data_100_random/NGC_2_random_19.ecsv
# Saved file: data_100_random/NGC_2_random_20.ecsv
# Saved file: data_100_random/NGC_2_random_21.ecsv
# Saved file: data_100_random/NGC_2_random_22.ecsv
# Saved file: data_100_random/NGC_2_random_23.ecsv
# Saved file: data_100_random/NGC_2_random_24.ecsv
# Saved file: data_100_random/NGC_2_random_25.ecsv
# Saved file: data_100_random/NGC_2_random_26.ecsv
# Saved file: data_100_random/NGC_2_random_27.ecsv
# Saved file: data_100_random/NGC_2_random_28.ecsv
# Saved file: data_100_random/NGC_2_random_29.ecsv
# Saved file: data_100_random/NGC_2_random_30.ecsv
# Saved file: data_100_random/NGC_2_random_31.ecsv
# Saved file: data_100_random/NGC_2_random_32.ecsv
# Saved file: data_100_random/NGC_2_random_33.ecsv
# Saved file: data_100_random/NGC_2_random_34.ecsv
# Saved file: data_100_random/NGC_2_random_35.ecsv
# Saved file: data_100_random/NGC_2_random_36.ecsv
# Saved file: data_100_random/NGC_2_random_37.ecsv
# Saved file: data_100_random/NGC_2_random_38.ecsv
# Saved file: data_100_random/NGC_2_random_39.ecsv
# Saved file: data_100_random/NGC_2_random_40.ecsv
# Saved file: data_100_random/NGC_2_random_41.ecsv
# Saved file: data_100_random/NGC_2_random_42.ecsv
# Saved file: data_100_random/NGC_2_random_43.ecsv
# Saved file: data_100_random/NGC_2_random_44.ecsv
# Saved file: data_100_random/NGC_2_random_45.ecsv
# Saved file: data_100_random/NGC_2_random_46.ecsv
# Saved file: data_100_random/NGC_2_random_47.ecsv
# Saved file: data_100_random/NGC_2_random_48.ecsv
# Saved file: data_100_random/NGC_2_random_49.ecsv
# Saved file: data_100_random/NGC_2_random_50.ecsv
# Saved file: data_100_random/NGC_2_random_51.ecsv
# Saved file: data_100_random/NGC_2_random_52.ecsv
# Saved file: data_100_random/NGC_2_random_53.ecsv
# Saved file: data_100_random/NGC_2_random_54.ecsv
# Saved file: data_100_random/NGC_2_random_55.ecsv
# Saved file: data_100_random/NGC_2_random_56.ecsv
# Saved file: data_100_random/NGC_2_random_57.ecsv
# Saved file: data_100_random/NGC_2_random_58.ecsv
# Saved file: data_100_random/NGC_2_random_59.ecsv
# Saved file: data_100_random/NGC_2_random_60.ecsv
# Saved file: data_100_random/NGC_2_random_61.ecsv
# Saved file: data_100_random/NGC_2_random_62.ecsv
# Saved file: data_100_random/NGC_2_random_63.ecsv
# Saved file: data_100_random/NGC_2_random_64.ecsv
# Saved file: data_100_random/NGC_2_random_65.ecsv
# Saved file: data_100_random/NGC_2_random_66.ecsv
# Saved file: data_100_random/NGC_2_random_67.ecsv
# Saved file: data_100_random/NGC_2_random_68.ecsv
# Saved file: data_100_random/NGC_2_random_69.ecsv
# Saved file: data_100_random/NGC_2_random_70.ecsv
# Saved file: data_100_random/NGC_2_random_71.ecsv
# Saved file: data_100_random/NGC_2_random_72.ecsv
# Saved file: data_100_random/NGC_2_random_73.ecsv
# Saved file: data_100_random/NGC_2_random_74.ecsv
# Saved file: data_100_random/NGC_2_random_75.ecsv
# Saved file: data_100_random/NGC_2_random_76.ecsv
# Saved file: data_100_random/NGC_2_random_77.ecsv
# Saved file: data_100_random/NGC_2_random_78.ecsv
# Saved file: data_100_random/NGC_2_random_79.ecsv
# Saved file: data_100_random/NGC_2_random_80.ecsv
# Saved file: data_100_random/NGC_2_random_81.ecsv
# Saved file: data_100_random/NGC_2_random_82.ecsv
# Saved file: data_100_random/NGC_2_random_83.ecsv
# Saved file: data_100_random/NGC_2_random_84.ecsv
# Saved file: data_100_random/NGC_2_random_85.ecsv
# Saved file: data_100_random/NGC_2_random_86.ecsv
# Saved file: data_100_random/NGC_2_random_87.ecsv
# Saved file: data_100_random/NGC_2_random_88.ecsv
# Saved file: data_100_random/NGC_2_random_89.ecsv
# Saved file: data_100_random/NGC_2_random_90.ecsv
# Saved file: data_100_random/NGC_2_random_91.ecsv
# Saved file: data_100_random/NGC_2_random_92.ecsv
# Saved file: data_100_random/NGC_2_random_93.ecsv
# Saved file: data_100_random/NGC_2_random_94.ecsv
# Saved file: data_100_random/NGC_2_random_95.ecsv
# Saved file: data_100_random/NGC_2_random_96.ecsv
# Saved file: data_100_random/NGC_2_random_97.ecsv
# Saved file: data_100_random/NGC_2_random_98.ecsv
# Saved file: data_100_random/NGC_2_random_99.ecsv
