# %%
from astropy.cosmology import Planck18
from astropy.coordinates import SkyCoord
import astropy.units as u

from astropy.table import Table, Column
import pandas as pd
import os
import glob
import random

# %%
# original files are found here https://data.desi.lbl.gov/public/edr/vac/edr/lss/v2.0/LSScats/clustering/
lss_data_N = Table.read("data/QSO_N_clustering.dat.fits")
lss_data_S = Table.read("data/QSO_S_clustering.dat.fits")

# %%
# Filter one-dimensional columns
names_N = [name for name in lss_data_N.colnames if len(lss_data_N[name].shape) <= 1]
names_S = [name for name in lss_data_S.colnames if len(lss_data_S[name].shape) <= 1]

# Convert to pandas DataFrame with only valid columns
df_N = lss_data_N[names_N].to_pandas()
df_S = lss_data_S[names_S].to_pandas()

# Concatenate both DataFrames
df_total = pd.concat([df_N, df_S], ignore_index=True)
df_total.rename(columns={'Z': 'REDSHIFT'}, inplace=True)

# %%
# Group by ROSETTE_NUMBER
df = {}
for rosette in sorted(df_total['ROSETTE_NUMBER'].unique()):
    df[rosette] = df_total[df_total['ROSETTE_NUMBER'] == rosette].copy()

# %% [markdown]
# # For random file:

# %%
cosmo = Planck18 # define cosmology

# %%
ran_files_N = sorted(glob.glob("data/QSO_N_*_clustering.ran.fits"))
ran_files_S = sorted(glob.glob("data/QSO_S_*_clustering.ran.fits"))

# %%
# ROSETTE_NUMBERs per hemisphere
rosettas_N = set(lss_data_N['ROSETTE_NUMBER'])
rosettas_S = set(lss_data_S['ROSETTE_NUMBER'])

# %%
# Number of random files per rosette
n_randoms = 100

for i in range(len(df)):
    rosetta = df[i]['ROSETTE_NUMBER'].iloc[0]
    n_rows = len(df[i])

    # File selection by hemisphere
    if rosetta in rosettas_N:
        ran_files = ran_files_N
        used_ran = set()
        hemisphere = "N"
    elif rosetta in rosettas_S:
        ran_files = ran_files_S
        used_ran = set()
        hemisphere = "S"

    for j in range(n_randoms):
        # If we have already used all the files, we allow them again
        if len(used_ran) == len(ran_files):
            used_ran = set()

        # Choose available .ran file
        candidates = [f for f in ran_files if f not in used_ran]
        ran_file = random.choice(candidates)
        used_ran.add(ran_file)

        print(f"→ df[{i}] random #{j+1} uses: {ran_file}")

        # Read and process random file
        ran_table = Table.read(ran_file)
        ran_full_df = ran_table.to_pandas()

        ran_filtered_df = ran_full_df[ran_full_df['ROSETTE_NUMBER'] == rosetta]

        ran_df = ran_filtered_df.sample(n=n_rows, random_state=j).reset_index(drop=True)

        # Comoving distance and cartesian coordinates
        z_ran = ran_df['Z'].values
        d_comov = cosmo.comoving_distance(z_ran).to(u.Mpc)
        ran_df['COMOVING_DISTANCE'] = d_comov.value

        coords = SkyCoord(ra=ran_df['RA'].values * u.deg,
                          dec=ran_df['DEC'].values * u.deg,
                          distance=d_comov)

        x = Column(coords.cartesian.x.to(u.Mpc), name='X')
        y = Column(coords.cartesian.y.to(u.Mpc), name='Y')
        z = Column(coords.cartesian.z.to(u.Mpc), name='Z')
        targetid = Column(ran_df['TARGETID'], name='TARGETID')

        output_table = Table([targetid, x, y, z])
        filename = f"data_100_random/QSO_{i}_clustering_random_{j}.ecsv"
        output_table.write(filename, format='ascii.ecsv', overwrite=True)
        print(f"✔️ Saved file: {filename}")
# Out:
# → df[0] random #1 uses: data\QSO_S_8_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_0.ecsv
# → df[0] random #2 uses: data\QSO_S_4_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_1.ecsv
# → df[0] random #3 uses: data\QSO_S_11_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_2.ecsv
# → df[0] random #4 uses: data\QSO_S_12_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_3.ecsv
# → df[0] random #5 uses: data\QSO_S_6_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_4.ecsv
# → df[0] random #6 uses: data\QSO_S_14_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_5.ecsv
# → df[0] random #7 uses: data\QSO_S_9_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_6.ecsv
# → df[0] random #8 uses: data\QSO_S_10_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_7.ecsv
# → df[0] random #9 uses: data\QSO_S_1_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_8.ecsv
# → df[0] random #10 uses: data\QSO_S_5_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_9.ecsv
# → df[0] random #11 uses: data\QSO_S_17_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_10.ecsv
# → df[0] random #12 uses: data\QSO_S_15_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_11.ecsv
# → df[0] random #13 uses: data\QSO_S_13_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_12.ecsv
# → df[0] random #14 uses: data\QSO_S_3_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_13.ecsv
# → df[0] random #15 uses: data\QSO_S_7_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_14.ecsv
# → df[0] random #16 uses: data\QSO_S_0_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_15.ecsv
# → df[0] random #17 uses: data\QSO_S_2_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_16.ecsv
# → df[0] random #18 uses: data\QSO_S_16_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_17.ecsv
# → df[0] random #19 uses: data\QSO_S_7_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_18.ecsv
# → df[0] random #20 uses: data\QSO_S_5_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_19.ecsv
# → df[0] random #21 uses: data\QSO_S_4_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_20.ecsv
# → df[0] random #22 uses: data\QSO_S_0_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_21.ecsv
# → df[0] random #23 uses: data\QSO_S_11_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_22.ecsv
# → df[0] random #24 uses: data\QSO_S_3_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_23.ecsv
# → df[0] random #25 uses: data\QSO_S_17_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_24.ecsv
# → df[0] random #26 uses: data\QSO_S_6_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_25.ecsv
# → df[0] random #27 uses: data\QSO_S_15_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_26.ecsv
# → df[0] random #28 uses: data\QSO_S_14_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_27.ecsv
# → df[0] random #29 uses: data\QSO_S_1_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_28.ecsv
# → df[0] random #30 uses: data\QSO_S_13_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_29.ecsv
# → df[0] random #31 uses: data\QSO_S_12_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_30.ecsv
# → df[0] random #32 uses: data\QSO_S_2_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_31.ecsv
# → df[0] random #33 uses: data\QSO_S_10_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_32.ecsv
# → df[0] random #34 uses: data\QSO_S_16_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_33.ecsv
# → df[0] random #35 uses: data\QSO_S_9_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_34.ecsv
# → df[0] random #36 uses: data\QSO_S_8_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_35.ecsv
# → df[0] random #37 uses: data\QSO_S_13_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_36.ecsv
# → df[0] random #38 uses: data\QSO_S_7_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_37.ecsv
# → df[0] random #39 uses: data\QSO_S_6_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_38.ecsv
# → df[0] random #40 uses: data\QSO_S_4_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_39.ecsv
# → df[0] random #41 uses: data\QSO_S_15_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_40.ecsv
# → df[0] random #42 uses: data\QSO_S_3_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_41.ecsv
# → df[0] random #43 uses: data\QSO_S_14_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_42.ecsv
# → df[0] random #44 uses: data\QSO_S_12_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_43.ecsv
# → df[0] random #45 uses: data\QSO_S_11_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_44.ecsv
# → df[0] random #46 uses: data\QSO_S_17_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_45.ecsv
# → df[0] random #47 uses: data\QSO_S_1_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_46.ecsv
# → df[0] random #48 uses: data\QSO_S_8_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_47.ecsv
# → df[0] random #49 uses: data\QSO_S_16_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_48.ecsv
# → df[0] random #50 uses: data\QSO_S_9_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_49.ecsv
# → df[0] random #51 uses: data\QSO_S_2_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_50.ecsv
# → df[0] random #52 uses: data\QSO_S_5_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_51.ecsv
# → df[0] random #53 uses: data\QSO_S_10_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_52.ecsv
# → df[0] random #54 uses: data\QSO_S_0_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_53.ecsv
# → df[0] random #55 uses: data\QSO_S_6_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_54.ecsv
# → df[0] random #56 uses: data\QSO_S_4_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_55.ecsv
# → df[0] random #57 uses: data\QSO_S_1_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_56.ecsv
# → df[0] random #58 uses: data\QSO_S_0_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_57.ecsv
# → df[0] random #59 uses: data\QSO_S_17_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_58.ecsv
# → df[0] random #60 uses: data\QSO_S_16_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_59.ecsv
# → df[0] random #61 uses: data\QSO_S_9_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_60.ecsv
# → df[0] random #62 uses: data\QSO_S_11_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_61.ecsv
# → df[0] random #63 uses: data\QSO_S_15_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_62.ecsv
# → df[0] random #64 uses: data\QSO_S_7_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_63.ecsv
# → df[0] random #65 uses: data\QSO_S_10_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_64.ecsv
# → df[0] random #66 uses: data\QSO_S_12_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_65.ecsv
# → df[0] random #67 uses: data\QSO_S_13_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_66.ecsv
# → df[0] random #68 uses: data\QSO_S_8_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_67.ecsv
# → df[0] random #69 uses: data\QSO_S_3_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_68.ecsv
# → df[0] random #70 uses: data\QSO_S_5_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_69.ecsv
# → df[0] random #71 uses: data\QSO_S_14_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_70.ecsv
# → df[0] random #72 uses: data\QSO_S_2_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_71.ecsv
# → df[0] random #73 uses: data\QSO_S_17_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_72.ecsv
# → df[0] random #74 uses: data\QSO_S_13_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_73.ecsv
# → df[0] random #75 uses: data\QSO_S_9_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_74.ecsv
# → df[0] random #76 uses: data\QSO_S_10_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_75.ecsv
# → df[0] random #77 uses: data\QSO_S_16_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_76.ecsv
# → df[0] random #78 uses: data\QSO_S_2_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_77.ecsv
# → df[0] random #79 uses: data\QSO_S_11_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_78.ecsv
# → df[0] random #80 uses: data\QSO_S_14_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_79.ecsv
# → df[0] random #81 uses: data\QSO_S_0_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_80.ecsv
# → df[0] random #82 uses: data\QSO_S_5_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_81.ecsv
# → df[0] random #83 uses: data\QSO_S_6_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_82.ecsv
# → df[0] random #84 uses: data\QSO_S_15_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_83.ecsv
# → df[0] random #85 uses: data\QSO_S_8_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_84.ecsv
# → df[0] random #86 uses: data\QSO_S_12_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_85.ecsv
# → df[0] random #87 uses: data\QSO_S_7_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_86.ecsv
# → df[0] random #88 uses: data\QSO_S_3_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_87.ecsv
# → df[0] random #89 uses: data\QSO_S_1_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_88.ecsv
# → df[0] random #90 uses: data\QSO_S_4_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_89.ecsv
# → df[0] random #91 uses: data\QSO_S_10_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_90.ecsv
# → df[0] random #92 uses: data\QSO_S_17_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_91.ecsv
# → df[0] random #93 uses: data\QSO_S_8_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_92.ecsv
# → df[0] random #94 uses: data\QSO_S_5_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_93.ecsv
# → df[0] random #95 uses: data\QSO_S_2_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_94.ecsv
# → df[0] random #96 uses: data\QSO_S_3_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_95.ecsv
# → df[0] random #97 uses: data\QSO_S_11_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_96.ecsv
# → df[0] random #98 uses: data\QSO_S_0_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_97.ecsv
# → df[0] random #99 uses: data\QSO_S_12_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_98.ecsv
# → df[0] random #100 uses: data\QSO_S_4_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_0_clustering_random_99.ecsv
# → df[1] random #1 uses: data\QSO_S_2_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_0.ecsv
# → df[1] random #2 uses: data\QSO_S_3_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_1.ecsv
# → df[1] random #3 uses: data\QSO_S_17_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_2.ecsv
# → df[1] random #4 uses: data\QSO_S_9_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_3.ecsv
# → df[1] random #5 uses: data\QSO_S_4_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_4.ecsv
# → df[1] random #6 uses: data\QSO_S_11_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_5.ecsv
# → df[1] random #7 uses: data\QSO_S_14_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_6.ecsv
# → df[1] random #8 uses: data\QSO_S_16_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_7.ecsv
# → df[1] random #9 uses: data\QSO_S_0_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_8.ecsv
# → df[1] random #10 uses: data\QSO_S_13_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_9.ecsv
# → df[1] random #11 uses: data\QSO_S_10_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_10.ecsv
# → df[1] random #12 uses: data\QSO_S_12_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_11.ecsv
# → df[1] random #13 uses: data\QSO_S_5_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_12.ecsv
# → df[1] random #14 uses: data\QSO_S_1_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_13.ecsv
# → df[1] random #15 uses: data\QSO_S_6_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_14.ecsv
# → df[1] random #16 uses: data\QSO_S_15_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_15.ecsv
# → df[1] random #17 uses: data\QSO_S_8_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_16.ecsv
# → df[1] random #18 uses: data\QSO_S_7_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_17.ecsv
# → df[1] random #19 uses: data\QSO_S_17_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_18.ecsv
# → df[1] random #20 uses: data\QSO_S_3_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_19.ecsv
# → df[1] random #21 uses: data\QSO_S_2_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_20.ecsv
# → df[1] random #22 uses: data\QSO_S_0_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_21.ecsv
# → df[1] random #23 uses: data\QSO_S_13_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_22.ecsv
# → df[1] random #24 uses: data\QSO_S_14_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_23.ecsv
# → df[1] random #25 uses: data\QSO_S_1_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_24.ecsv
# → df[1] random #26 uses: data\QSO_S_4_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_25.ecsv
# → df[1] random #27 uses: data\QSO_S_10_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_26.ecsv
# → df[1] random #28 uses: data\QSO_S_11_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_27.ecsv
# → df[1] random #29 uses: data\QSO_S_9_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_28.ecsv
# → df[1] random #30 uses: data\QSO_S_15_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_29.ecsv
# → df[1] random #31 uses: data\QSO_S_7_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_30.ecsv
# → df[1] random #32 uses: data\QSO_S_6_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_31.ecsv
# → df[1] random #33 uses: data\QSO_S_16_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_32.ecsv
# → df[1] random #34 uses: data\QSO_S_8_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_33.ecsv
# → df[1] random #35 uses: data\QSO_S_12_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_34.ecsv
# → df[1] random #36 uses: data\QSO_S_5_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_35.ecsv
# → df[1] random #37 uses: data\QSO_S_13_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_36.ecsv
# → df[1] random #38 uses: data\QSO_S_2_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_37.ecsv
# → df[1] random #39 uses: data\QSO_S_16_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_38.ecsv
# → df[1] random #40 uses: data\QSO_S_12_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_39.ecsv
# → df[1] random #41 uses: data\QSO_S_5_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_40.ecsv
# → df[1] random #42 uses: data\QSO_S_15_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_41.ecsv
# → df[1] random #43 uses: data\QSO_S_1_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_42.ecsv
# → df[1] random #44 uses: data\QSO_S_10_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_43.ecsv
# → df[1] random #45 uses: data\QSO_S_9_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_44.ecsv
# → df[1] random #46 uses: data\QSO_S_0_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_45.ecsv
# → df[1] random #47 uses: data\QSO_S_14_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_46.ecsv
# → df[1] random #48 uses: data\QSO_S_8_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_47.ecsv
# → df[1] random #49 uses: data\QSO_S_11_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_48.ecsv
# → df[1] random #50 uses: data\QSO_S_7_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_49.ecsv
# → df[1] random #51 uses: data\QSO_S_4_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_50.ecsv
# → df[1] random #52 uses: data\QSO_S_6_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_51.ecsv
# → df[1] random #53 uses: data\QSO_S_17_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_52.ecsv
# → df[1] random #54 uses: data\QSO_S_3_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_53.ecsv
# → df[1] random #55 uses: data\QSO_S_8_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_54.ecsv
# → df[1] random #56 uses: data\QSO_S_2_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_55.ecsv
# → df[1] random #57 uses: data\QSO_S_16_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_56.ecsv
# → df[1] random #58 uses: data\QSO_S_10_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_57.ecsv
# → df[1] random #59 uses: data\QSO_S_11_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_58.ecsv
# → df[1] random #60 uses: data\QSO_S_7_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_59.ecsv
# → df[1] random #61 uses: data\QSO_S_4_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_60.ecsv
# → df[1] random #62 uses: data\QSO_S_17_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_61.ecsv
# → df[1] random #63 uses: data\QSO_S_6_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_62.ecsv
# → df[1] random #64 uses: data\QSO_S_1_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_63.ecsv
# → df[1] random #65 uses: data\QSO_S_13_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_64.ecsv
# → df[1] random #66 uses: data\QSO_S_15_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_65.ecsv
# → df[1] random #67 uses: data\QSO_S_0_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_66.ecsv
# → df[1] random #68 uses: data\QSO_S_14_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_67.ecsv
# → df[1] random #69 uses: data\QSO_S_3_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_68.ecsv
# → df[1] random #70 uses: data\QSO_S_9_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_69.ecsv
# → df[1] random #71 uses: data\QSO_S_12_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_70.ecsv
# → df[1] random #72 uses: data\QSO_S_5_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_71.ecsv
# → df[1] random #73 uses: data\QSO_S_2_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_72.ecsv
# → df[1] random #74 uses: data\QSO_S_11_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_73.ecsv
# → df[1] random #75 uses: data\QSO_S_7_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_74.ecsv
# → df[1] random #76 uses: data\QSO_S_0_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_75.ecsv
# → df[1] random #77 uses: data\QSO_S_6_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_76.ecsv
# → df[1] random #78 uses: data\QSO_S_15_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_77.ecsv
# → df[1] random #79 uses: data\QSO_S_17_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_78.ecsv
# → df[1] random #80 uses: data\QSO_S_13_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_79.ecsv
# → df[1] random #81 uses: data\QSO_S_16_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_80.ecsv
# → df[1] random #82 uses: data\QSO_S_10_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_81.ecsv
# → df[1] random #83 uses: data\QSO_S_4_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_82.ecsv
# → df[1] random #84 uses: data\QSO_S_9_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_83.ecsv
# → df[1] random #85 uses: data\QSO_S_14_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_84.ecsv
# → df[1] random #86 uses: data\QSO_S_1_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_85.ecsv
# → df[1] random #87 uses: data\QSO_S_8_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_86.ecsv
# → df[1] random #88 uses: data\QSO_S_12_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_87.ecsv
# → df[1] random #89 uses: data\QSO_S_5_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_88.ecsv
# → df[1] random #90 uses: data\QSO_S_3_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_89.ecsv
# → df[1] random #91 uses: data\QSO_S_12_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_90.ecsv
# → df[1] random #92 uses: data\QSO_S_5_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_91.ecsv
# → df[1] random #93 uses: data\QSO_S_10_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_92.ecsv
# → df[1] random #94 uses: data\QSO_S_15_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_93.ecsv
# → df[1] random #95 uses: data\QSO_S_14_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_94.ecsv
# → df[1] random #96 uses: data\QSO_S_6_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_95.ecsv
# → df[1] random #97 uses: data\QSO_S_8_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_96.ecsv
# → df[1] random #98 uses: data\QSO_S_13_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_97.ecsv
# → df[1] random #99 uses: data\QSO_S_17_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_98.ecsv
# → df[1] random #100 uses: data\QSO_S_7_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_1_clustering_random_99.ecsv
# → df[2] random #1 uses: data\QSO_S_9_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_0.ecsv
# → df[2] random #2 uses: data\QSO_S_11_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_1.ecsv
# → df[2] random #3 uses: data\QSO_S_17_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_2.ecsv
# → df[2] random #4 uses: data\QSO_S_12_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_3.ecsv
# → df[2] random #5 uses: data\QSO_S_1_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_4.ecsv
# → df[2] random #6 uses: data\QSO_S_5_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_5.ecsv
# → df[2] random #7 uses: data\QSO_S_16_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_6.ecsv
# → df[2] random #8 uses: data\QSO_S_2_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_7.ecsv
# → df[2] random #9 uses: data\QSO_S_10_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_8.ecsv
# → df[2] random #10 uses: data\QSO_S_15_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_9.ecsv
# → df[2] random #11 uses: data\QSO_S_4_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_10.ecsv
# → df[2] random #12 uses: data\QSO_S_6_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_11.ecsv
# → df[2] random #13 uses: data\QSO_S_8_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_12.ecsv
# → df[2] random #14 uses: data\QSO_S_14_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_13.ecsv
# → df[2] random #15 uses: data\QSO_S_13_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_14.ecsv
# → df[2] random #16 uses: data\QSO_S_3_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_15.ecsv
# → df[2] random #17 uses: data\QSO_S_7_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_16.ecsv
# → df[2] random #18 uses: data\QSO_S_0_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_17.ecsv
# → df[2] random #19 uses: data\QSO_S_2_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_18.ecsv
# → df[2] random #20 uses: data\QSO_S_4_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_19.ecsv
# → df[2] random #21 uses: data\QSO_S_5_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_20.ecsv
# → df[2] random #22 uses: data\QSO_S_8_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_21.ecsv
# → df[2] random #23 uses: data\QSO_S_7_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_22.ecsv
# → df[2] random #24 uses: data\QSO_S_14_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_23.ecsv
# → df[2] random #25 uses: data\QSO_S_1_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_24.ecsv
# → df[2] random #26 uses: data\QSO_S_3_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_25.ecsv
# → df[2] random #27 uses: data\QSO_S_0_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_26.ecsv
# → df[2] random #28 uses: data\QSO_S_15_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_27.ecsv
# → df[2] random #29 uses: data\QSO_S_17_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_28.ecsv
# → df[2] random #30 uses: data\QSO_S_16_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_29.ecsv
# → df[2] random #31 uses: data\QSO_S_13_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_30.ecsv
# → df[2] random #32 uses: data\QSO_S_12_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_31.ecsv
# → df[2] random #33 uses: data\QSO_S_10_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_32.ecsv
# → df[2] random #34 uses: data\QSO_S_11_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_33.ecsv
# → df[2] random #35 uses: data\QSO_S_6_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_34.ecsv
# → df[2] random #36 uses: data\QSO_S_9_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_35.ecsv
# → df[2] random #37 uses: data\QSO_S_4_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_36.ecsv
# → df[2] random #38 uses: data\QSO_S_14_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_37.ecsv
# → df[2] random #39 uses: data\QSO_S_8_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_38.ecsv
# → df[2] random #40 uses: data\QSO_S_6_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_39.ecsv
# → df[2] random #41 uses: data\QSO_S_12_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_40.ecsv
# → df[2] random #42 uses: data\QSO_S_1_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_41.ecsv
# → df[2] random #43 uses: data\QSO_S_15_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_42.ecsv
# → df[2] random #44 uses: data\QSO_S_3_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_43.ecsv
# → df[2] random #45 uses: data\QSO_S_7_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_44.ecsv
# → df[2] random #46 uses: data\QSO_S_13_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_45.ecsv
# → df[2] random #47 uses: data\QSO_S_11_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_46.ecsv
# → df[2] random #48 uses: data\QSO_S_16_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_47.ecsv
# → df[2] random #49 uses: data\QSO_S_17_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_48.ecsv
# → df[2] random #50 uses: data\QSO_S_0_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_49.ecsv
# → df[2] random #51 uses: data\QSO_S_2_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_50.ecsv
# → df[2] random #52 uses: data\QSO_S_10_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_51.ecsv
# → df[2] random #53 uses: data\QSO_S_9_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_52.ecsv
# → df[2] random #54 uses: data\QSO_S_5_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_53.ecsv
# → df[2] random #55 uses: data\QSO_S_4_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_54.ecsv
# → df[2] random #56 uses: data\QSO_S_8_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_55.ecsv
# → df[2] random #57 uses: data\QSO_S_2_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_56.ecsv
# → df[2] random #58 uses: data\QSO_S_13_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_57.ecsv
# → df[2] random #59 uses: data\QSO_S_11_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_58.ecsv
# → df[2] random #60 uses: data\QSO_S_15_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_59.ecsv
# → df[2] random #61 uses: data\QSO_S_10_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_60.ecsv
# → df[2] random #62 uses: data\QSO_S_16_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_61.ecsv
# → df[2] random #63 uses: data\QSO_S_1_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_62.ecsv
# → df[2] random #64 uses: data\QSO_S_12_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_63.ecsv
# → df[2] random #65 uses: data\QSO_S_9_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_64.ecsv
# → df[2] random #66 uses: data\QSO_S_0_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_65.ecsv
# → df[2] random #67 uses: data\QSO_S_3_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_66.ecsv
# → df[2] random #68 uses: data\QSO_S_14_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_67.ecsv
# → df[2] random #69 uses: data\QSO_S_7_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_68.ecsv
# → df[2] random #70 uses: data\QSO_S_5_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_69.ecsv
# → df[2] random #71 uses: data\QSO_S_6_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_70.ecsv
# → df[2] random #72 uses: data\QSO_S_17_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_71.ecsv
# → df[2] random #73 uses: data\QSO_S_0_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_72.ecsv
# → df[2] random #74 uses: data\QSO_S_8_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_73.ecsv
# → df[2] random #75 uses: data\QSO_S_14_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_74.ecsv
# → df[2] random #76 uses: data\QSO_S_6_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_75.ecsv
# → df[2] random #77 uses: data\QSO_S_15_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_76.ecsv
# → df[2] random #78 uses: data\QSO_S_3_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_77.ecsv
# → df[2] random #79 uses: data\QSO_S_16_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_78.ecsv
# → df[2] random #80 uses: data\QSO_S_13_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_79.ecsv
# → df[2] random #81 uses: data\QSO_S_7_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_80.ecsv
# → df[2] random #82 uses: data\QSO_S_4_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_81.ecsv
# → df[2] random #83 uses: data\QSO_S_5_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_82.ecsv
# → df[2] random #84 uses: data\QSO_S_12_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_83.ecsv
# → df[2] random #85 uses: data\QSO_S_2_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_84.ecsv
# → df[2] random #86 uses: data\QSO_S_1_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_85.ecsv
# → df[2] random #87 uses: data\QSO_S_10_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_86.ecsv
# → df[2] random #88 uses: data\QSO_S_11_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_87.ecsv
# → df[2] random #89 uses: data\QSO_S_17_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_88.ecsv
# → df[2] random #90 uses: data\QSO_S_9_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_89.ecsv
# → df[2] random #91 uses: data\QSO_S_5_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_90.ecsv
# → df[2] random #92 uses: data\QSO_S_3_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_91.ecsv
# → df[2] random #93 uses: data\QSO_S_11_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_92.ecsv
# → df[2] random #94 uses: data\QSO_S_16_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_93.ecsv
# → df[2] random #95 uses: data\QSO_S_6_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_94.ecsv
# → df[2] random #96 uses: data\QSO_S_15_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_95.ecsv
# → df[2] random #97 uses: data\QSO_S_9_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_96.ecsv
# → df[2] random #98 uses: data\QSO_S_14_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_97.ecsv
# → df[2] random #99 uses: data\QSO_S_4_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_98.ecsv
# → df[2] random #100 uses: data\QSO_S_10_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_2_clustering_random_99.ecsv
# → df[3] random #1 uses: data\QSO_N_1_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_0.ecsv
# → df[3] random #2 uses: data\QSO_N_16_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_1.ecsv
# → df[3] random #3 uses: data\QSO_N_3_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_2.ecsv
# → df[3] random #4 uses: data\QSO_N_2_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_3.ecsv
# → df[3] random #5 uses: data\QSO_N_4_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_4.ecsv
# → df[3] random #6 uses: data\QSO_N_13_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_5.ecsv
# → df[3] random #7 uses: data\QSO_N_5_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_6.ecsv
# → df[3] random #8 uses: data\QSO_N_9_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_7.ecsv
# → df[3] random #9 uses: data\QSO_N_11_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_8.ecsv
# → df[3] random #10 uses: data\QSO_N_10_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_9.ecsv
# → df[3] random #11 uses: data\QSO_N_6_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_10.ecsv
# → df[3] random #12 uses: data\QSO_N_15_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_11.ecsv
# → df[3] random #13 uses: data\QSO_N_14_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_12.ecsv
# → df[3] random #14 uses: data\QSO_N_7_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_13.ecsv
# → df[3] random #15 uses: data\QSO_N_12_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_14.ecsv
# → df[3] random #16 uses: data\QSO_N_17_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_15.ecsv
# → df[3] random #17 uses: data\QSO_N_8_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_16.ecsv
# → df[3] random #18 uses: data\QSO_N_0_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_17.ecsv
# → df[3] random #19 uses: data\QSO_N_6_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_18.ecsv
# → df[3] random #20 uses: data\QSO_N_12_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_19.ecsv
# → df[3] random #21 uses: data\QSO_N_14_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_20.ecsv
# → df[3] random #22 uses: data\QSO_N_10_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_21.ecsv
# → df[3] random #23 uses: data\QSO_N_15_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_22.ecsv
# → df[3] random #24 uses: data\QSO_N_17_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_23.ecsv
# → df[3] random #25 uses: data\QSO_N_16_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_24.ecsv
# → df[3] random #26 uses: data\QSO_N_4_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_25.ecsv
# → df[3] random #27 uses: data\QSO_N_7_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_26.ecsv
# → df[3] random #28 uses: data\QSO_N_13_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_27.ecsv
# → df[3] random #29 uses: data\QSO_N_3_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_28.ecsv
# → df[3] random #30 uses: data\QSO_N_9_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_29.ecsv
# → df[3] random #31 uses: data\QSO_N_11_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_30.ecsv
# → df[3] random #32 uses: data\QSO_N_1_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_31.ecsv
# → df[3] random #33 uses: data\QSO_N_0_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_32.ecsv
# → df[3] random #34 uses: data\QSO_N_2_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_33.ecsv
# → df[3] random #35 uses: data\QSO_N_5_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_34.ecsv
# → df[3] random #36 uses: data\QSO_N_8_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_35.ecsv
# → df[3] random #37 uses: data\QSO_N_0_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_36.ecsv
# → df[3] random #38 uses: data\QSO_N_3_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_37.ecsv
# → df[3] random #39 uses: data\QSO_N_15_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_38.ecsv
# → df[3] random #40 uses: data\QSO_N_12_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_39.ecsv
# → df[3] random #41 uses: data\QSO_N_1_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_40.ecsv
# → df[3] random #42 uses: data\QSO_N_11_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_41.ecsv
# → df[3] random #43 uses: data\QSO_N_17_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_42.ecsv
# → df[3] random #44 uses: data\QSO_N_13_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_43.ecsv
# → df[3] random #45 uses: data\QSO_N_10_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_44.ecsv
# → df[3] random #46 uses: data\QSO_N_2_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_45.ecsv
# → df[3] random #47 uses: data\QSO_N_7_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_46.ecsv
# → df[3] random #48 uses: data\QSO_N_6_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_47.ecsv
# → df[3] random #49 uses: data\QSO_N_14_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_48.ecsv
# → df[3] random #50 uses: data\QSO_N_8_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_49.ecsv
# → df[3] random #51 uses: data\QSO_N_9_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_50.ecsv
# → df[3] random #52 uses: data\QSO_N_5_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_51.ecsv
# → df[3] random #53 uses: data\QSO_N_4_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_52.ecsv
# → df[3] random #54 uses: data\QSO_N_16_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_53.ecsv
# → df[3] random #55 uses: data\QSO_N_6_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_54.ecsv
# → df[3] random #56 uses: data\QSO_N_8_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_55.ecsv
# → df[3] random #57 uses: data\QSO_N_3_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_56.ecsv
# → df[3] random #58 uses: data\QSO_N_11_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_57.ecsv
# → df[3] random #59 uses: data\QSO_N_10_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_58.ecsv
# → df[3] random #60 uses: data\QSO_N_12_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_59.ecsv
# → df[3] random #61 uses: data\QSO_N_0_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_60.ecsv
# → df[3] random #62 uses: data\QSO_N_15_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_61.ecsv
# → df[3] random #63 uses: data\QSO_N_17_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_62.ecsv
# → df[3] random #64 uses: data\QSO_N_5_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_63.ecsv
# → df[3] random #65 uses: data\QSO_N_14_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_64.ecsv
# → df[3] random #66 uses: data\QSO_N_1_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_65.ecsv
# → df[3] random #67 uses: data\QSO_N_16_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_66.ecsv
# → df[3] random #68 uses: data\QSO_N_4_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_67.ecsv
# → df[3] random #69 uses: data\QSO_N_13_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_68.ecsv
# → df[3] random #70 uses: data\QSO_N_2_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_69.ecsv
# → df[3] random #71 uses: data\QSO_N_7_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_70.ecsv
# → df[3] random #72 uses: data\QSO_N_9_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_71.ecsv
# → df[3] random #73 uses: data\QSO_N_12_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_72.ecsv
# → df[3] random #74 uses: data\QSO_N_15_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_73.ecsv
# → df[3] random #75 uses: data\QSO_N_6_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_74.ecsv
# → df[3] random #76 uses: data\QSO_N_4_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_75.ecsv
# → df[3] random #77 uses: data\QSO_N_14_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_76.ecsv
# → df[3] random #78 uses: data\QSO_N_3_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_77.ecsv
# → df[3] random #79 uses: data\QSO_N_17_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_78.ecsv
# → df[3] random #80 uses: data\QSO_N_5_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_79.ecsv
# → df[3] random #81 uses: data\QSO_N_0_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_80.ecsv
# → df[3] random #82 uses: data\QSO_N_9_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_81.ecsv
# → df[3] random #83 uses: data\QSO_N_2_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_82.ecsv
# → df[3] random #84 uses: data\QSO_N_1_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_83.ecsv
# → df[3] random #85 uses: data\QSO_N_8_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_84.ecsv
# → df[3] random #86 uses: data\QSO_N_16_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_85.ecsv
# → df[3] random #87 uses: data\QSO_N_7_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_86.ecsv
# → df[3] random #88 uses: data\QSO_N_11_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_87.ecsv
# → df[3] random #89 uses: data\QSO_N_13_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_88.ecsv
# → df[3] random #90 uses: data\QSO_N_10_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_89.ecsv
# → df[3] random #91 uses: data\QSO_N_2_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_90.ecsv
# → df[3] random #92 uses: data\QSO_N_15_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_91.ecsv
# → df[3] random #93 uses: data\QSO_N_5_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_92.ecsv
# → df[3] random #94 uses: data\QSO_N_9_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_93.ecsv
# → df[3] random #95 uses: data\QSO_N_10_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_3_clustering_random_94.ecsv
# → df[3] random #96 uses: data\QSO_N_13_clustering.ran.fits
# ...
# ✔️ Saved file: data_100_random/QSO_18_clustering_random_70.ecsv
# → df[18] random #72 uses: data\QSO_N_7_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_18_clustering_random_71.ecsv
# → df[18] random #73 uses: data\QSO_N_8_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_18_clustering_random_72.ecsv
# → df[18] random #74 uses: data\QSO_N_13_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_18_clustering_random_73.ecsv
# → df[18] random #75 uses: data\QSO_N_6_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_18_clustering_random_74.ecsv
# → df[18] random #76 uses: data\QSO_N_15_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_18_clustering_random_75.ecsv
# → df[18] random #77 uses: data\QSO_N_3_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_18_clustering_random_76.ecsv
# → df[18] random #78 uses: data\QSO_N_0_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_18_clustering_random_77.ecsv
# → df[18] random #79 uses: data\QSO_N_5_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_18_clustering_random_78.ecsv
# → df[18] random #80 uses: data\QSO_N_4_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_18_clustering_random_79.ecsv
# → df[18] random #81 uses: data\QSO_N_16_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_18_clustering_random_80.ecsv
# → df[18] random #82 uses: data\QSO_N_10_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_18_clustering_random_81.ecsv
# → df[18] random #83 uses: data\QSO_N_9_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_18_clustering_random_82.ecsv
# → df[18] random #84 uses: data\QSO_N_2_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_18_clustering_random_83.ecsv
# → df[18] random #85 uses: data\QSO_N_12_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_18_clustering_random_84.ecsv
# → df[18] random #86 uses: data\QSO_N_1_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_18_clustering_random_85.ecsv
# → df[18] random #87 uses: data\QSO_N_7_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_18_clustering_random_86.ecsv
# → df[18] random #88 uses: data\QSO_N_14_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_18_clustering_random_87.ecsv
# → df[18] random #89 uses: data\QSO_N_17_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_18_clustering_random_88.ecsv
# → df[18] random #90 uses: data\QSO_N_11_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_18_clustering_random_89.ecsv
# → df[18] random #91 uses: data\QSO_N_12_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_18_clustering_random_90.ecsv
# → df[18] random #92 uses: data\QSO_N_6_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_18_clustering_random_91.ecsv
# → df[18] random #93 uses: data\QSO_N_9_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_18_clustering_random_92.ecsv
# → df[18] random #94 uses: data\QSO_N_1_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_18_clustering_random_93.ecsv
# → df[18] random #95 uses: data\QSO_N_0_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_18_clustering_random_94.ecsv
# → df[18] random #96 uses: data\QSO_N_5_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_18_clustering_random_95.ecsv
# → df[18] random #97 uses: data\QSO_N_16_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_18_clustering_random_96.ecsv
# → df[18] random #98 uses: data\QSO_N_15_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_18_clustering_random_97.ecsv
# → df[18] random #99 uses: data\QSO_N_11_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_18_clustering_random_98.ecsv
# → df[18] random #100 uses: data\QSO_N_2_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_18_clustering_random_99.ecsv
# → df[19] random #1 uses: data\QSO_N_14_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_0.ecsv
# → df[19] random #2 uses: data\QSO_N_5_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_1.ecsv
# → df[19] random #3 uses: data\QSO_N_8_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_2.ecsv
# → df[19] random #4 uses: data\QSO_N_2_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_3.ecsv
# → df[19] random #5 uses: data\QSO_N_17_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_4.ecsv
# → df[19] random #6 uses: data\QSO_N_12_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_5.ecsv
# → df[19] random #7 uses: data\QSO_N_0_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_6.ecsv
# → df[19] random #8 uses: data\QSO_N_7_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_7.ecsv
# → df[19] random #9 uses: data\QSO_N_4_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_8.ecsv
# → df[19] random #10 uses: data\QSO_N_11_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_9.ecsv
# → df[19] random #11 uses: data\QSO_N_6_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_10.ecsv
# → df[19] random #12 uses: data\QSO_N_16_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_11.ecsv
# → df[19] random #13 uses: data\QSO_N_9_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_12.ecsv
# → df[19] random #14 uses: data\QSO_N_10_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_13.ecsv
# → df[19] random #15 uses: data\QSO_N_3_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_14.ecsv
# → df[19] random #16 uses: data\QSO_N_15_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_15.ecsv
# → df[19] random #17 uses: data\QSO_N_13_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_16.ecsv
# → df[19] random #18 uses: data\QSO_N_1_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_17.ecsv
# → df[19] random #19 uses: data\QSO_N_4_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_18.ecsv
# → df[19] random #20 uses: data\QSO_N_5_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_19.ecsv
# → df[19] random #21 uses: data\QSO_N_13_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_20.ecsv
# → df[19] random #22 uses: data\QSO_N_0_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_21.ecsv
# → df[19] random #23 uses: data\QSO_N_9_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_22.ecsv
# → df[19] random #24 uses: data\QSO_N_15_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_23.ecsv
# → df[19] random #25 uses: data\QSO_N_11_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_24.ecsv
# → df[19] random #26 uses: data\QSO_N_2_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_25.ecsv
# → df[19] random #27 uses: data\QSO_N_3_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_26.ecsv
# → df[19] random #28 uses: data\QSO_N_16_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_27.ecsv
# → df[19] random #29 uses: data\QSO_N_6_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_28.ecsv
# → df[19] random #30 uses: data\QSO_N_7_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_29.ecsv
# → df[19] random #31 uses: data\QSO_N_10_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_30.ecsv
# → df[19] random #32 uses: data\QSO_N_8_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_31.ecsv
# → df[19] random #33 uses: data\QSO_N_12_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_32.ecsv
# → df[19] random #34 uses: data\QSO_N_17_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_33.ecsv
# → df[19] random #35 uses: data\QSO_N_14_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_34.ecsv
# → df[19] random #36 uses: data\QSO_N_1_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_35.ecsv
# → df[19] random #37 uses: data\QSO_N_1_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_36.ecsv
# → df[19] random #38 uses: data\QSO_N_9_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_37.ecsv
# → df[19] random #39 uses: data\QSO_N_11_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_38.ecsv
# → df[19] random #40 uses: data\QSO_N_2_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_39.ecsv
# → df[19] random #41 uses: data\QSO_N_0_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_40.ecsv
# → df[19] random #42 uses: data\QSO_N_16_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_41.ecsv
# → df[19] random #43 uses: data\QSO_N_14_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_42.ecsv
# → df[19] random #44 uses: data\QSO_N_17_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_43.ecsv
# → df[19] random #45 uses: data\QSO_N_7_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_44.ecsv
# → df[19] random #46 uses: data\QSO_N_5_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_45.ecsv
# → df[19] random #47 uses: data\QSO_N_4_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_46.ecsv
# → df[19] random #48 uses: data\QSO_N_3_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_47.ecsv
# → df[19] random #49 uses: data\QSO_N_13_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_48.ecsv
# → df[19] random #50 uses: data\QSO_N_12_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_49.ecsv
# → df[19] random #51 uses: data\QSO_N_6_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_50.ecsv
# → df[19] random #52 uses: data\QSO_N_8_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_51.ecsv
# → df[19] random #53 uses: data\QSO_N_10_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_52.ecsv
# → df[19] random #54 uses: data\QSO_N_15_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_53.ecsv
# → df[19] random #55 uses: data\QSO_N_10_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_54.ecsv
# → df[19] random #56 uses: data\QSO_N_14_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_55.ecsv
# → df[19] random #57 uses: data\QSO_N_17_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_56.ecsv
# → df[19] random #58 uses: data\QSO_N_4_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_57.ecsv
# → df[19] random #59 uses: data\QSO_N_6_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_58.ecsv
# → df[19] random #60 uses: data\QSO_N_12_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_59.ecsv
# → df[19] random #61 uses: data\QSO_N_2_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_60.ecsv
# → df[19] random #62 uses: data\QSO_N_8_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_61.ecsv
# → df[19] random #63 uses: data\QSO_N_16_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_62.ecsv
# → df[19] random #64 uses: data\QSO_N_7_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_63.ecsv
# → df[19] random #65 uses: data\QSO_N_13_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_64.ecsv
# → df[19] random #66 uses: data\QSO_N_11_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_65.ecsv
# → df[19] random #67 uses: data\QSO_N_1_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_66.ecsv
# → df[19] random #68 uses: data\QSO_N_5_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_67.ecsv
# → df[19] random #69 uses: data\QSO_N_15_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_68.ecsv
# → df[19] random #70 uses: data\QSO_N_0_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_69.ecsv
# → df[19] random #71 uses: data\QSO_N_3_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_70.ecsv
# → df[19] random #72 uses: data\QSO_N_9_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_71.ecsv
# → df[19] random #73 uses: data\QSO_N_6_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_72.ecsv
# → df[19] random #74 uses: data\QSO_N_11_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_73.ecsv
# → df[19] random #75 uses: data\QSO_N_17_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_74.ecsv
# → df[19] random #76 uses: data\QSO_N_16_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_75.ecsv
# → df[19] random #77 uses: data\QSO_N_3_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_76.ecsv
# → df[19] random #78 uses: data\QSO_N_14_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_77.ecsv
# → df[19] random #79 uses: data\QSO_N_7_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_78.ecsv
# → df[19] random #80 uses: data\QSO_N_4_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_79.ecsv
# → df[19] random #81 uses: data\QSO_N_15_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_80.ecsv
# → df[19] random #82 uses: data\QSO_N_5_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_81.ecsv
# → df[19] random #83 uses: data\QSO_N_1_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_82.ecsv
# → df[19] random #84 uses: data\QSO_N_9_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_83.ecsv
# → df[19] random #85 uses: data\QSO_N_12_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_84.ecsv
# → df[19] random #86 uses: data\QSO_N_8_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_85.ecsv
# → df[19] random #87 uses: data\QSO_N_0_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_86.ecsv
# → df[19] random #88 uses: data\QSO_N_13_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_87.ecsv
# → df[19] random #89 uses: data\QSO_N_2_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_88.ecsv
# → df[19] random #90 uses: data\QSO_N_10_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_89.ecsv
# → df[19] random #91 uses: data\QSO_N_15_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_90.ecsv
# → df[19] random #92 uses: data\QSO_N_1_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_91.ecsv
# → df[19] random #93 uses: data\QSO_N_4_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_92.ecsv
# → df[19] random #94 uses: data\QSO_N_12_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_93.ecsv
# → df[19] random #95 uses: data\QSO_N_16_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_94.ecsv
# → df[19] random #96 uses: data\QSO_N_17_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_95.ecsv
# → df[19] random #97 uses: data\QSO_N_7_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_96.ecsv
# → df[19] random #98 uses: data\QSO_N_9_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_97.ecsv
# → df[19] random #99 uses: data\QSO_N_11_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_98.ecsv
# → df[19] random #100 uses: data\QSO_N_13_clustering.ran.fits
# ✔️ Saved file: data_100_random/QSO_19_clustering_random_99.ecsv
